# %%
from celery import current_task

# %%
current_task.request
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5982/908081443.py in <module>
# ----> 1 current_task.request
#
# ~/anaconda3/envs/tf14-gpu/lib/python3.7/site-packages/celery/local.py in __getattr__(self, name)
#     146         if name == '__members__':
#     147             return dir(self._get_current_object())
# --> 148         return getattr(self._get_current_object(), name)
#     149
#     150     def __setitem__(self, key, value):
#
# AttributeError: 'NoneType' object has no attribute 'request'

# %%
from runCelery import plot 
x = []
file_in = open('/home/prakash/BayesianCeleryRun/output.txt', 'r')
for y in file_in.read().split('\n'):
    #print (y)
    
    y = str(y).replace('[','').replace(']','')
    if y!='':
        x.append(float(y))
    #print (float(y))
    #print (type(y))
    #if y.isdigit():
file_in.close()
#print (x)
plot(x,None)
# Out:
# In /home/prakash/anaconda3/envs/tf14-gpu/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/prakash/anaconda3/envs/tf14-gpu/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/prakash/anaconda3/envs/tf14-gpu/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/prakash/anaconda3/envs/tf14-gpu/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# ...
